# %%
from sklearn import tree as j48
from SupervisedLearning.Experiments import GetData as helperfn

# %%
# Example of how to get randomised data from a file in the 'Data' folder
x, y = helperfn.get_data(result_id=1)
x.shape, y.shape
# Out:
# ((9690, 2304), (9690, 1))

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x, y)

# %%
j48.plot_tree(clf)
# Out:
# 6\nvalue = [52, 4]'),
#  Text(236.55752895752897, 97.27578947368421, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(238.62579150579154, 97.27578947368421, 'X[1659] <= 125.0\ngini = 0.071\nsamples = 54\nvalue = [52, 2]'),
#  Text(237.59166023166026, 85.83157894736843, 'X[590] <= 122.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(236.55752895752897, 74.38736842105263, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(238.62579150579154, 74.38736842105263, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(239.65992277992282, 85.83157894736843, 'gini = 0.0\nsamples = 51\nvalue = [51, 0]'),
#  Text(241.72818532818536, 108.72, 'X[1377] <= 113.0\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(240.69405405405408, 97.27578947368421, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(242.76231660231664, 97.27578947368421, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
# ...
